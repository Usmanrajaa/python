# %%
import numpy as np

# %%
np.genfromtxt("p1.csv",delimiter=',')
# Out:
# array([[nan, nan, nan],
#        [nan, nan, 40.],
#        [nan, nan, 90.],
#        [nan, nan, 80.]])

# %%
np.genfromtxt("p2.csv",delimiter=',')
# Out:
# array([[ 1.,  2.,  3.,  4.,  5.],
#        [ 5., nan,  7.,  8.,  9.],
#        [ 9.,  2.,  7., nan, 12.]])

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PIL import Image

# %%
a=Image.open("test_image.webp")

# %%
a.size
# Out:
# (1536, 864)

# %%
b=np.array(a)

# %%
np.save("share_test_image.npy",b)

# %%
z=np.load("share_test_image.npy")

# %%
z[0][0][0]=60

# %%
z
# Out:
# array([[[60, 35, 43],
#         [25, 35, 43],
#         [25, 35, 43],
#         ...,
#         [29, 36, 47],
#         [29, 36, 47],
#         [29, 36, 47]],
#
#        [[25, 35, 43],
#         [25, 35, 43],
#         [25, 35, 43],
#         ...,
#         [29, 36, 47],
#         [29, 36, 47],
#         [29, 36, 47]],
#
#        [[25, 35, 43],
#         [25, 35, 43],
#         [25, 35, 43],
#         ...,
#         [29, 36, 47],
#         [29, 36, 47],
#         [29, 36, 47]],
#
#        ...,
#
#        [[27, 71, 86],
#         [27, 71, 86],
#         [27, 71, 86],
#         ...,
#         [26, 34, 41],
#         [26, 34, 41],
#         [26, 34, 41]],
#
#        [[27, 71, 86],
#         [27, 71, 86],
#         [27, 71, 86],
#         ...,
#         [26, 34, 41],
#         [26, 34, 41],
#         [26, 34, 41]],
#
#        [[27, 71, 86],
#         [27, 71, 86],
#         [27, 71, 86],
#         ...,
#         [26, 34, 41],
#         [26, 34, 41],
# ...

# %%
Image.fromarray(z)
# Out:
# <PIL.Image.Image image mode=RGB size=1536x864>
