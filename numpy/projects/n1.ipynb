# %%
import numpy as np

# %%
np.genfromtxt("p1.csv",delimiter=',')
# Out:
# array([[nan, nan, nan],
#        [nan, nan, 40.],
#        [nan, nan, 90.],
#        [nan, nan, 80.]])

# %%
np.genfromtxt("p2.csv",delimiter=',')
# Out:
# array([[ 1.,  2.,  3.,  4.,  5.],
#        [ 5., nan,  7.,  8.,  9.],
#        [ 9.,  2.,  7., nan, 12.]])

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PIL import Image

# %%
a=Image.open("agent_ai.webp")

# %%
a.size
# Out:
# (1024, 1024)

# %%
b=np.array(a)

# %%
np.save("share_Image.npy",b)

# %%
c=np.load("share_Image.npy")

# %%
Image.fromarray(c)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
