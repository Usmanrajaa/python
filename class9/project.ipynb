# %% [markdown]
# ## make a student record system where name and roll no. get written eveytime in a file student.txt.

# %%
name=input("enter name")
roll_no=input("enter roll no.")

with open("student.txt","a") as f:  #f=open("student.txt","a")
    f.write("name is"+name+"and roll no is"+roll_no+"\n")
