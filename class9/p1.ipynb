# %%
## open("file_name","mode")

f1=open("practice1.txt","r")
f1.read()
# Out:
# 'hello guys, welcome to kapil sharma show.be seated and enjoy the night with full of fun I hope the moments would be enjoyable.\nthe most funniest person is sunil grovar and krishna . while former member was sudesh lahri he was also too down to earth and funny \nartist.whole nation enjoyed al lot.'

# %%
f=open("practice1.csv","r")
f.read()
# Out:
# 'name,subject,marks\nraj,physics,99\nhritik,math,78\n'

# %%
f=open("practice1.txt","a")
f.write(" I hope the moments would be enjoyable")
f.close()

# %%
f=open("practice1.txt","r")
f.read()
# Out:
# 'hello guys, welcome to kapil sharma show.be seated and enjoy the night with full of fun I hope the moments would be enjoyable.\nthe most funniest person is sunil grovar and krishna . while former member was sudesh lahri he was also too down to earth and funny \nartist.whole nation enjoyed al lot. I hope the moments would be enjoyable'

# %%
## make a table of 4 columns which has 
## employee_Name, salary, residence, company_name
## fill at least 5 rows data
