# %%
# Problems on primitive data types in Python

# Problem 1: Identify the primitive data types
# What are the primitive data types in Python? List them and give an example for each.

# Problem 2: Type checking
# Write code to check the type of the following values:
# - 42
# - 3.14
# - "Hello"
# - True
# - 2 + 3j

# Problem 3: Type conversion
# Convert the integer 10 to a float, then to a string, and check the types after each conversion.

# Problem 4: Boolean operations
# Evaluate the following expressions and determine their boolean values:
# - 5 > 3
# - "apple" == "Apple"
# - not False
# - 0 == False

# %%
a=5
b=50
a,b=b,a

# %%
print(a)
print(b)
# Out:
# 50
# 5

# %%
#solution 1:
# will identify the primitive datatypes by seeing the count of values a variables stores. if there is only one values with respect to one variable
# then it means it is primitive datatypes
# primitive data types: int (i.e. 2,3 etc.),string(i.e "a","b" etc.),float(i.e 3.4,5.6 etc),boolean(i.e true,false)

# %%
#Solution 2:
# Write code to check the type of the following values:
a=42  
b=3.14
c="Hello"
d=True
e=2 + 3j

print(type(a),type(b),type(c),type(d),type(e))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'> <class 'complex'>

# %%
a=45
complex(a)
# Out:
# (45+0j)

# %%
b=4+5j
int(b.real)
# Out:
# 4

# %%
# Problem 4: Boolean operations
# Evaluate the following expressions and determine their boolean values:
a=5 > 3
b="apple" == "Apple"
c=not False
d=0 == False

# %%
a
# Out:
# True

# %%
b
# Out:
# False

# %%
c
# Out:
# True

# %%
d
# Out:
# True

# %%
a=56
a=str(a)
type(a)
# Out:
# str

# %%
a=60
a=90
print(a)
# Out:
# 90
