# %%
import matplotlib.pyplot as plt

# %%
a=[1,2,3,4,5]
b=[10,20,30,40,50]

# %%
plt.plot(a,b)
plt.xlabel("days")
plt.ylabel("sales")
plt.title("days vs sales trend")
# Out:
# Text(0.5, 1.0, 'days vs sales trend')

# %%
import pandas as pd

# %%
df=pd.read_csv("Spotify_songs_Analytics_Data.csv")

# %%
df.head(10)
# Out:
#          date  position               song                      artist  \
# 0  18-05-2023         1    Ella Baila Sola              Eslabon Armado
# 1  18-05-2023         2          un x100to  Grupo Frontera & Bad Bunny
# 2  18-05-2023         3    La Bebe - Remix      Yng Lvcas & Peso Pluma
# 3  18-05-2023         4  Cupid - Twin Ver.                 FIFTY FIFTY
# 4  18-05-2023         5            Flowers                 Miley Cyrus
# 5  18-05-2023         6           Daylight               David Kushner
# 6  18-05-2023         7          Kill Bill                         SZA
# 7  18-05-2023         8             Tattoo                      Loreen
# 8  18-05-2023         9          As It Was                Harry Styles
# 9  18-05-2023        10                TQG                     KAROL G
#
#    popularity  duration_ms album_type  total_tracks release_date  is_explicit  \
# 0          89       165671      album            16   28-04-2023        False
# ...

# %%
x=df["album_type"]
y=df["total_tracks"]

# %%
x=x[0:20]
y=y[0:20]

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.subplot(1,3,1)
plt.plot(a,b)
plt.title("a vs b")
plt.subplot(1,3,2)
plt.plot(x,y)
plt.title("x vs y")
plt.subplot(1,3,3)
plt.plot(x,y)
plt.title("x vs y")
# Out:
# Text(0.5, 1.0, 'x vs y')

# %%
print(x)
print(y)
# Out:
# 0      album
# 1     single
# 2     single
# 3     single
# 4      album
# 5     single
# 6      album
# 7     single
# 8      album
# 9      album
# 10    single
# 11    single
# 12    single
# 13     album
# 14     album
# 15    single
# 16     album
# 17    single
# 18     album
# 19     album
# Name: album_type, dtype: object
# 0     16
# 1      1
# 2      2
# 3      3
# 4     13
# 5      1
# 6     23
# 7      1
# 8     13
# 9     17
# 10     1
# 11     1
# 12     1
# 13    15
# 14    14
# 15     3
# 16    21
# 17     1
# 18    22
# 19    17
# Name: total_tracks, dtype: int64

# %%
plt.pie(y,labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e3eab09730>,
# ...
#  [Text(1.0600762055058766, 0.2936638188818343, 'album'),
#   Text(0.9335086697442408, 0.5818604330183811, 'single'),
#   Text(0.9028398000681418, 0.6283950154265373, 'single'),
#   Text(0.8466163630153646, 0.7023109951258322, 'single'),
#   Text(0.6283949759621542, 0.9028398275361604, 'album'),
#   Text(0.39940317633231254, 1.0249278524538494, 'single'),
#   Text(-0.03715161361554295, 1.099372438078089, 'album'),
#   Text(-0.46768470788313143, 0.995625940809233, 'single'),
#   Text(-0.6879119941184308, 0.8583572032365105, 'album'),
#   Text(-1.018035914149547, 0.41665678621822133, 'album'),
#   Text(-1.0960797140530167, 0.09278610047554181, 'single'),
#   Text(-1.0985881487542521, 0.055714265827572176, 'single'),
#   Text(-1.0998430959302283, 0.01857859883335796, 'single'),
#   Text(-1.0648848545372462, -0.27571769362372794, 'album'),
#   Text(-0.8099582384744953, -0.7442900321294736, 'album'),
# ...

# %%
plt.scatter(x,y)

# %%
plt.hist(y,bins=3)
# Out:
# (array([10.,  4.,  6.]),
#  array([ 1.        ,  8.33333333, 15.66666667, 23.        ]),
#  <BarContainer object of 3 artists>)
