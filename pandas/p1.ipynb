# %% [markdown]
# ## Pandas

# %%
! pip install pandas
# Out:
# ...
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import pandas as pd

# %% [markdown]
# # 1.CREATE

# %% [markdown]
# #### 1.1 Create series manually

# %%
data=[3,4,5,6,7,8]

# %%
pd.Series(data)
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# 5    8
# dtype: int64

# %%
pd.Series(data,index=['a','b','c','d','e','f'])
# Out:
# a    3
# b    4
# c    5
# d    6
# e    7
# f    8
# dtype: int64

# %%
a={"a":10,"b":20,"c":30,"d":40,"e":50}

# %%
pd.Series(a)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# #### 2. Create DataFrame Manually

# %% [markdown]
# #### method1. From a Dictionary of Lists

# %%
data={
    "name":["aman","ajay","krish"],
    "age":[20,30,40],
    "profession":["sde","da","ds"]
}

# %%
pd.DataFrame(data)
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df =pd.DataFrame(data)

# %% [markdown]
# #### method2. From a List of Dictionaries

# %%
data=[
    {'name':'a','age':20,'score':60,'subject':"math"},
    {'name':'b','age':30,'score':70,'subject':"physcis"},
    {'name':'c','age':40,'score':80,'subject':"chemistry"},
    {'name':'d','age':50,'score':90,'subject':"bio"}
]

# %%
pd.DataFrame(data)
# Out:
#   name  age  score    subject
# 0    a   20     60       math
# 1    b   30     70    physcis
# 2    c   40     80  chemistry
# 3    d   50     90        bio

# %% [markdown]
# #### 3. List Of Lists

# %%
data=[
    ["a",20,60,"math"],
    ["b",30,70,"physcis"]
]

# %%
pd.DataFrame(data,columns=['name','age','score','subject'])
# Out:
#   name  age  score  subject
# 0    a   20     60     math
# 1    b   30     70  physcis

# %% [markdown]
# # 2. Access

# %%
data1={
    "name":["aman","ajay","krish"],
    "age":[20,30,40],
    "profession":["sde","da","ds"]
}

# %%
# pd.DataFrame(data1,index=["a","b","c"])

# %%
df=pd.DataFrame(data1)

# %%
df
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df["profession"]
# Out:
# 0    sde
# 1     da
# 2     ds
# Name: profession, dtype: object

# %%
df[["age","profession"]]
# Out:
#    age profession
# 0   20        sde
# 1   30         da
# 2   40         ds

# %%
df
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
# label-based
df.loc[2]
# Out:
# name          krish
# age              40
# profession       ds
# Name: 2, dtype: object

# %%
df.loc[2]["name"]
# Out:
# 'krish'

# %%
df.loc[1:2]
# Out:
#     name  age profession
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df.index=['R01','R02','R03']

# %%
df
# Out:
#       name  age profession
# R01   aman   20        sde
# R02   ajay   30         da
# R03  krish   40         ds

# %%
df.loc['R02', 'profession']
# Out:
# 'da'

# %%
data2={
    "name":["aman","ajay","krish"],
    "age":[20,30,40],
    "profession":["sde","da","ds"]
}

# %%
df1 =pd.DataFrame(data2)

# %%
df1
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df1.loc[1,'profession']
# Out:
# 'da'

# %%
df1
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df1[["name","profession"]]
# Out:
#     name profession
# 0   aman        sde
# 1   ajay         da
# 2  krish         ds

# %%
df1.iloc[0:3]
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df1.iloc[:,0:2]
# Out:
#     name  age
# 0   aman   20
# 1   ajay   30
# 2  krish   40

# %%
df1.iloc[0:2]
# Out:
#    name  age profession
# 0  aman   20        sde
# 1  ajay   30         da

# %%
l=["name","age","profession"]

# %%
l[0:2]
# Out:
# ['name', 'age']

# %%
data1={
    "name":["aman","ajay","krish"],
    "age":[20,30,40],
    "profession":["sde","da","ds"]
}

# %%
df=pd.DataFrame(data1)

# %%
df
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df.iloc[:,0:1]
# Out:
#     name
# 0   aman
# 1   ajay
# 2  krish

# %%
df.iloc[:,2:3]
# Out:
#   profession
# 0        sde
# 1         da
# 2         ds

# %%
## ajay's age?
df.iloc[1:2,0:2]
# Out:
#    name  age
# 1  ajay   30

# %% [markdown]
# # 3. Edit

# %%
df1
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
df1["name"]=["a","b","c"]

# %%
df1
# Out:
#   name  age profession
# 0    a   20        sde
# 1    b   30         da
# 2    c   40         ds

# %%
df1.loc[1, "profession"] = "ba"

# %%
df1
# Out:
#   name  age profession
# 0    a   20        sde
# 1    b   30         ba
# 2    c   40         ds

# %%
df1.loc[2]=["m",30,"da"]

# %%
df1
# Out:
#   name  age profession
# 0    a   20        sde
# 1    b   30         ba
# 2    m   30         da

# %%
df1.rename(columns={"profession":"designation"},inplace=True)

# %%
df1
# Out:
#   name  age designation
# 0    a   20         sde
# 1    b   30          ba
# 2    m   30          da

# %% [markdown]
# # 4. add

# %%
df1
# Out:
#   name  age designation
# 0    a   20         sde
# 1    b   30          ba
# 2    m   30          da

# %%
df1["work_location"]=["bangalore","mumbai","delhi"]

# %%
df1
# Out:
#   name  age designation work_location
# 0    a   20         sde     bangalore
# 1    b   30          ba        mumbai
# 2    m   30          da         delhi

# %%
df1.loc[0,"name"]="z"

# %%
df1.iloc[0,0]="m"

# %%
df1.iloc[1,1]=40

# %%
df1
# Out:
#   name  age designation work_location
# 0    m   20         sde     bangalore
# 1    b   40          ba        mumbai
# 2    m   30          da       chennai

# %% [markdown]
# ## 5. Delete

# %%
df1
# Out:
#   name  age designation work_location
# 0    m   20         sde     bangalore
# 1    b   40          ba        mumbai
# 2    m   30          da       chennai

# %%
df1=df1.drop("age",axis=1)

# %%
df1
# Out:
#   name designation work_location
# 0    m         sde     bangalore
# 1    b          ba        mumbai
# 2    m          da       chennai

# %%
df1.drop(2,axis=0)
# Out:
#   name  age designation work_location
# 0    m   20         sde     bangalore
# 1    b   40          ba        mumbai

# %%
df1["designation"]=["a","b","c"]

# %%
df1
# Out:
#   name designation work_location
# 0    m           a     bangalore
# 1    b           b        mumbai
# 2    m           c       chennai

# %%
data3={
    "name":["aman","ajay","krish"],
    "age":[20,30,40],
    "profession":["sde","da","ds"],
}

# %%
df3=pd.DataFrame(data3)
df3
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds

# %%
new_column={"profession":["a","b","c"]}
df4=pd.DataFrame(new_column)
df4
# Out:
#   profession
# 0          a
# 1          b
# 2          c

# %%
df5=pd.concat([df3,df4],axis=1)

# %%
df5
# Out:
#     name  age profession profession
# 0   aman   20        sde          a
# 1   ajay   30         da          b
# 2  krish   40         ds          c

# %%
df.columns
# Out:
# Index(['name', 'age', 'profession'], dtype='object')

# %%
df5.iloc[:, [i for i in range(len(df5.columns)) if i == 3]]
# Out:
#   profession
# 0          a
# 1          b
# 2          c

# %%
df
# Out:
#     name  age profession
# 0   aman   20        sde
# 1   ajay   30         da
# 2  krish   40         ds
