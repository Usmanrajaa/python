# %%
import pandas as pd

# %%
data=pd.read_csv("f1.csv")

# %%
data
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %%
data.head(10)
# Out:
#    Rank   Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1      1             2  $780,000,000                     $780,000,000
# 1     2      1          7[2]  $579,800,000                     $579,800,000
# 2     3   1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4   2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5   2[4]           NaN  $345,675,146                     $402,844,849
# 5     6   2[4]         10[9]  $305,158,363                     $388,978,496
# 6     7  2[10]           NaN  $280,000,000                     $381,932,682
# 7     7    NaN           NaN  $257,600,000                     $257,600,000
# 8     9    NaN           NaN  $256,084,556                     $312,258,401
# 9    10    NaN           NaN  $250,400,000                     $309,141,878
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# ...

# %%
data.tail(10)
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# 19    20    NaN           NaN     $150,000,000
#
#    Adjusted gross (in 2022 dollars)        Artist  \
# 10                     $283,202,896       Beyoncé
# 11                     $295,301,479     Lady Gaga
# 12                     $251,856,802    Katy Perry
# 13                     $299,676,265          Cher
# 14                     $281,617,035       Madonna
# 15                     $227,452,347          Pink
# 16                     $213,568,571     Lady Gaga
# ...

# %%
data.shape
# Out:
# (20, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      object
#  2   All Time Peak                     6 non-null      object
#  3   Actual gross                      20 non-null     object
#  4   Adjusted gross (in 2022 dollars)  20 non-null     object
#  5   Artist                            20 non-null     object
#  6   Tour title                        20 non-null     object
#  7   Year(s)                           20 non-null     object
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     object
#  10  Ref.                              20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %%
data.isnull().sum()
# Out:
# Rank                                 0
# Peak                                11
# All Time Peak                       14
# Actual gross                         0
# Adjusted gross (in 2022 dollars)     0
# Artist                               0
# Tour title                           0
# Year(s)                              0
# Shows                                0
# Average gross                        0
# Ref.                                 0
# dtype: int64

# %%
data.describe()
# Out:
#             Rank       Shows
# count  20.000000   20.000000
# mean   10.450000  110.000000
# std     5.942488   66.507617
# min     1.000000   41.000000
# 25%     5.750000   59.000000
# 50%    10.500000   87.000000
# 75%    15.250000  134.500000
# max    20.000000  325.000000

# %%
data.describe(include="all")
# Out:
#              Rank Peak All Time Peak  Actual gross  \
# count   20.000000    9             6            20
# unique        NaN    7             6            20
# top           NaN    1             2  $780,000,000
# freq          NaN    2             1             1
# mean    10.450000  NaN           NaN           NaN
# std      5.942488  NaN           NaN           NaN
# min      1.000000  NaN           NaN           NaN
# 25%      5.750000  NaN           NaN           NaN
# 50%     10.500000  NaN           NaN           NaN
# 75%     15.250000  NaN           NaN           NaN
# max     20.000000  NaN           NaN           NaN
#
#        Adjusted gross (in 2022 dollars)        Artist       Tour title  \
# count                                20            20               20
# unique                               20             9               20
# top                        $780,000,000  Taylor Swift  The Eras Tour †
# ...

# %%
data["Average gross"].describe()
# Out:
# count              20
# unique             20
# top       $13,928,571
# freq                1
# Name: Average gross, dtype: object

# %%
data['Average gross']
# Out:
# 0     $13,928,571
# 1     $10,353,571
# 2      $4,835,294
# 3      $2,546,795
# 4      $6,522,173
# 5      $3,467,709
# 6      $2,137,405
# 7      $6,282,927
# 8      $5,226,215
# 9      $2,945,882
# 10     $1,735,606
# 11     $1,118,227
# 12     $1,350,993
# 13       $615,385
# 14     $3,233,333
# 15     $1,295,775
# 16     $1,734,694
# 17     $2,070,732
# 18     $1,385,950
# 19     $1,744,186
# Name: Average gross, dtype: object

# %%
data['Average gross'][5]
# Out:
# '$3,467,709'

# %%
data['Rank'].duplicated().sum()
# Out:
# np.int64(1)

# %%
data['Rank'].nunique()
# Out:
# 19

# %%
data['Peak'].nunique()
# Out:
# 7

# %%
data['All Time Peak'].nunique()
# Out:
# 6

# %%
data['Rank'].nunique()
# Out:
# 19

# %%
data['Shows'].nunique()
# Out:
# 18

# %%
list(data.columns)
# Out:
# ['Rank',
#  'Peak',
#  'All Time Peak',
#  'Actual\xa0gross',
#  'Adjusted\xa0gross (in 2022 dollars)',
#  'Artist',
#  'Tour title',
#  'Year(s)',
#  'Shows',
#  'Average gross',
#  'Ref.']

# %%
data1=['Ref.','Tour title']

# %%
data.drop(columns='Ref.')
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %%
data.drop(columns=data1)
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %%
data['Peak'][4]="hello"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13136\668647420.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['Peak'][4]="hello"
# C:\Users\HP\AppData\Local\Temp\ipykernel_13136\668647420.py:1: SettingWithCopyWarning:
# ...

# %%
data
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5  hello           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...
