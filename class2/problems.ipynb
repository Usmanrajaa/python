# %%
## take a 3 digit user input and sum all digits.
## i.e.  user_input=594   , output=5+9+4=18

# %%
user_input=int(input("enter your three digit number:"))
first_digit=user_input%10
first_digit
user_input=user_input//10
user_input
second_digit=user_input%10
second_digit
user_input=user_input//10
user_input
third_digit=user_input%10
third_digit
output=first_digit+second_digit+third_digit
output
# Out:
# 12

# %%
user_input=int(input("enter digit:"))
print(user_input%10+(user_input//10)%10+user_input//100)
# Out:
# 12

# %%
# 1. Accept a 4-digit number from the user and print the sum of its digits.
# 2. Accept a number from the user and print the product of its digits.
# 3. Accept length and width from the user and calculate the area and perimeter of a rectangle.
# 4. Accept temperature in Celsius from the user and convert it to Fahrenheit.
# 5. Accept time in seconds from the user and convert it to hours, minutes, and seconds.
# 6. Accept a 5-digit number from the user and print its reverse.
# 7. Accept radius from the user and calculate the circumference and area of a circle.
# 8. Accept two integers from the user and swap their values without using a temporary variable.
# 9. Accept distance in kilometers from the user and convert it to meters and centimeters.
# 10. Accept a 3-digit number from the user and determine whether it is an Armstrong number.

# %%
# 1. Read a signed integer from input and use bitwise operators to determine whether it is even or odd,
#    without using modulus (%) or division (//, /), then print "Even" or "Odd".
# 2. Read two values from input, allow them to be integer or float, and use arithmetic and comparison
#    operators to determine whether their average lies strictly between the two values.
# 3. Accept a numeric string from input, convert it to an integer using only arithmetic operations and
#    string indexing, then compute (n + n//10) * (n % 10) using operator precedence.
# 4. Read three numeric inputs and use assignment operators plus logical operators to swap the first and
#    third values only if the second value is negative, otherwise keep them as entered.
# 5. Take a numeric input and use floor division, modulus, and exponentiation operators to extract its
#    digits and check whether the sum of the cubes of the digits equals the original number.
