# %%
## user input

# %%
x=int(input("give card no.:"))
print(x)
# Out:
# 80

# %%
y=bool(input("enter condition:"))

# %%
y
# Out:
# False

# %%
# 1. Read two integers from input and print their sum, difference, product, and integer division result.
# 2. Read a float and an integer from input, then print the result of adding them and the result of multiplying them.
# 3. Read a string and an integer from input, then print the string repeated that many times and its length.
# 4. Read two boolean values from input (as "True" or "False"), then print the results of AND, OR, and XOR operations.
# 5. Read an integer, a float, and a string from input, then print the integer converted to float plus the float,
#  and concatenate the string with the integer converted to string.

# %%
# get two numbers and print  which one is closure to 100.
# get three numbers and print them in ascending order using comparison operator
