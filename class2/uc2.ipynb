# %%
a=5
b=6
c=7

# %%
print(a,b,c)
# Out:
# 5 6 7

# %%
print(a);print(b);print(c)
# Out:
# 5
# 6
# 7

# %%
a=50
user=int(input("enter your no."))
print(a>user)
# Out:
# False

# %%
a=20
b=3
print(a/b)
# Out:
# 6.666666666666667

# %%
print(a//b)
# Out:
# 6

# %%
print(a%b)
# Out:
# 2
