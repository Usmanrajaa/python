# %% [markdown]
# ## PROBLEM-1

# %%
emails = [
    "alice_bravo@example.com",
    "bob@example",
    "charlie@example.com",
    "david@example.com",
    "eve@example.com",
    "frank@example.com",
    "grace@example.com",
    "alice@example.com"
]

## EXTRACT THE NAMES AND PUT IN A LIST .

# %%
a="hi @ i am alex"

# %%
a.split("@")
# Out:
# ['hi ', ' i am alex']

# %%
mail="alice@example.com"
mail.split("@")[0]
# Out:
# 'alice'

# %%
name_list=[]
for mail in emails:
    a=mail.split("@")[0]
    name_list.append(a)
print(name_list)
# Out:
# ['alice_bravo', 'bob', 'charlie', 'david', 'eve', 'frank', 'grace', 'alice']

# %%
name_list=[mail.split("@")[0] for mail in emails ]

# %%
name_list
# Out:
# ['alice_bravo', 'bob', 'charlie', 'david', 'eve', 'frank', 'grace', 'alice']

# %%
l5=[]
x="hello"
l5.append(x)

# %%
l5
# Out:
# ['hello']

# %%
# Problem 1: Remove duplicates preserving order
# Given a list `nums`, return a new list containing the first occurrence of each element in original order.
# Example: [3,1,2,3,2] -> [3,1,2]

# Problem 2: Rotate list in-place
# Given a list `nums` and integer k, rotate the list to the right by k steps in-place.
# Example: [1,2,3,4,5], k=2 -> [4,5,1,2,3]

# Problem 4: Merge overlapping intervals
# Given a list of intervals as [start, end], merge all overlapping intervals and return them sorted by start.
# Example: [[1,3],[2,6],[8,10],[15,18]] -> [[1,6],[8,10],[15,18]]

# Problem 5: Majority element (> n/2)
# Given a list `nums` where one element appears more than n/2 times, return that element. Aim for O(n) time and O(1) space.
# Example: [2,2,1,2,3,2] -> 2
