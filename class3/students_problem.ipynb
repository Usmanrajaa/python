# %%
## 1. create a list=[1,"raj",3.14,True,null]   print each element's type
## 2. create list [1,2,3,4,5] replace all even no. with 0.
## 3. find second highest value 
## 4. remove the smalles value from list a without using minimum function

# %%
## solution 1
l=[1,"raj",3.14,True,None]
print(type(l[0]),type(l[1]),type(l[2]),type(l[3]),type(l[4]))

## solution 2
l1=[1,2,3,4,5]
l1[1]=0
l1[3]=0
print(l1)
# Out:
# <class 'int'> <class 'str'> <class 'float'> <class 'bool'> <class 'NoneType'>
# [1, 0, 3, 0, 5]

# %%
# solution 3
l3=[56,2,3,90,67,34,25]
l3.sort()
l3[-2]
# Out:
# 67

# %%
# solution 4
l3.sort(reverse=True)
l3.pop()
l3
# Out:
# [90, 67, 56, 34, 25]

# %%
l5=[56,2,3,90,67,34,25]
l5.insert(0,25)
l5.pop()
l5
# Out:
# [25, 56, 2, 3, 90, 67, 34]

# %%
l5=[56,2,3,90,67,34,25,43,23,89,12]
l5=[l5[-1]]+l5[0:len(l5)-1]
l5

# l5=[l5[-1]]+l5[0:len(l5)-1]
# l5
# Out:
# [12, 56, 2, 3, 90, 67, 34, 25, 43, 23, 89]
