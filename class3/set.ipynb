# %% [markdown]
# ## SET
# ##### properties->:1. duplicates are not allowed 2. syntax=> {}  3. unordered(indexing not possible)
# #####              4. Diverse datatype possible

# %% [markdown]
# ## 1. CREATE

# %%
s1={1,2,4,2,9,2,8,7,2}

# %%
print(s1)
# Out:
# {1, 2, 4, 7, 8, 9}

# %%
s1
# Out:
# {1, 2, 4, 6, 7}

# %% [markdown]
# ## 2. Access

# %%
s2={1,2,4,2,9,2,8,7,"hi"}

# %%
s2[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s2[3]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ## 3. Edit

# %%
s2[3]=20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s2[3]=20
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# ## 4. add

# %%
s3={4,8,2,9}

# %%
s3.add(13)

# %%
s3
# Out:
# {2, 4, 8, 9, 13}

# %% [markdown]
# ## 5. delete

# %%
s4={6,4,5,2,8,9}

# %%
s4
# Out:
# {2, 4, 5, 6, 8, 9}

# %%
s4.pop()
# Out:
# 2

# %%
s4.remove(5)

# %%
s4
# Out:
# {4, 6, 8, 9}

# %% [markdown]
# ## 6. Operations

# %%
s1={4,5,5,6}
s2={9,8,2}

# %%
s1+s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s1+s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s1*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s1*3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %% [markdown]
# ## 7. functions

# %%
s5={9,3,2,8,7}

# %%
len(s5)
# Out:
# 5

# %%
max(s5)
# Out:
# 9

# %%
min(s5)
# Out:
# 2

# %%
## you receive a database export of customer email addressess containing several diplicates. 
# clean and remove duplicates
emails=["user1@test.com","user2@test.com","user1@test.com","user2@test.com"]

# %%
set(emails)
# Out:
# {'user1@test.com', 'user2@test.com'}

# %%
## there are two friends and their movie preferece lists are following
f1=["sci-fi","Action","Comedy","Thriller"]
f2=["Drama","Comedy","sci-fi","Romance"]

# find comman preference for both freind   ##(expected outpu={"sci-fi","Comedy"})

f1=set(f1)
f2=set(f2)

# %%
f1.intersection(f2)
# Out:
# {'Comedy', 'sci-fi'}

# %%
f1.difference(f2)
# Out:
# {'Action', 'Thriller'}

# %%
f2.difference(f1)
# Out:
# {'Drama', 'Romance'}

# %%
checklist=["Apple","banana","milk","bread","eggs"]
current_inventory=["Apple","milk"]

# %%
checklist=set(checklist)
current_inventory=set(current_inventory)

# %%
checklist.difference(current_inventory)
# Out:
# {'banana', 'bread', 'eggs'}

# %%
day_1=["user a","user b","user c","user d"]
day_2=["user e","user a","user x","user c","user y"]
day_1=set(day_1)
day_2=set(day_2)

# %%
unique_visitors=day_1.union(day_2)
unique_visitors
# Out:
# {'user a', 'user b', 'user c', 'user d', 'user e', 'user x', 'user y'}
