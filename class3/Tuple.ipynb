# %% [markdown]
# ## TUPLES
# ##### properties-> 1.diverse datatype possible 2. Ordered(indexing possible) 3.immutable, once created the tuple later can't be modified and deleted 4.duplicates allowed

# %% [markdown]
# ### 1. CREATE
# ### 2. ACCESS
# ### 3. EDIT
# ### 4. ADD
# ### 5. REMOVE
# ### 6. OPERATIONS
# ### 7. FUNCTIONS

# %% [markdown]
# ## 1. CREATE

# %%
t1=(2,3,4,5)
t1
# Out:
# (2, 3, 4, 5)

# %%
t2=(2,3,(5,6),8)
t2
# Out:
# (2, 3, (5, 6), 8)

# %%
t3=((2,3),(4,5),(6,8))
t3
# Out:
# ((2, 3), (4, 5), (6, 8))

# %% [markdown]
# ## 2. ACCESS

# %%
t4=(5,6,7,8,9)

# %%
t4[3]
# Out:
# 8

# %%
t4[2:5]
# Out:
# (7, 8, 9)

# %%
t4[-1]
# Out:
# 9

# %%
t4[2:5:2]
# Out:
# (7, 9)

# %%
t4[::-1]
# Out:
# (9, 8, 7, 6, 5)

# %% [markdown]
# ## 3. EDIT

# %%
t=(5,6,7,"hi")

# %%
t[3]
# Out:
# 'hi'

# %%
bank_customer_data
# Out:
# ['amaaan', 'ankit', 'raj']

# %%
t[3]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t[3]=10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## 4. ADD

# %%
t3=(3,4,6,7,9)

# %%
t5=(5,6,7,8)
t6=(9,0,3,4)
t5+t6
# Out:
# (5, 6, 7, 8, 9, 0, 3, 4)

# %%
t5*3
# Out:
# (5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8)

# %%
print(6 in t5)
# Out:
# True

# %% [markdown]
# ## 5. DELETE

# %%
t9=(5,6,2,3,4)

# %%
t9.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 t9.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t9.remove()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t9.remove()
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t9.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t9.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
del t9[4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 del t9[4]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# ### 6. OPERATIONS

# %%
t5=(4,56,89,4,5,4,98,4)
t6=(4,)
print(t5)
print(t6)
# Out:
# (4, 56, 89, 4, 5, 4, 98, 4)
# (4,)

# %%
m1=(4,5,6)
m2=(8,9,3)
m1+m2
# Out:
# (4, 5, 6, 8, 9, 3)

# %%
t5+t6
# Out:
# (4, 56, 89, 4, 5, 4, 98, 4, 4)

# %%
t5*2
# Out:
# (4, 56, 89, 4, 5, 4, 98, 4, 4, 56, 89, 4, 5, 4, 98, 4)

# %% [markdown]
# ## 7. FUNCTIONS

# %%
t5=(5,6,6,2,3,9,5,12)

# %%
min(t5)
# Out:
# 2

# %%
max(t5)
# Out:
# 12

# %%
len(t5)
# Out:
# 8

# %%
t5.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 t5.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
sorted(t5)
# Out:
# [2, 3, 5, 5, 6, 6, 9, 12]

# %%
sorted(t5,reverse=True)
# Out:
# [12, 9, 6, 6, 5, 5, 3, 2]

# %%
t5
# Out:
# (5, 6, 6, 2, 3, 9, 5, 12)

# %%
t5.count(9)
# Out:
# 1

# %%
sum(t5)
# Out:
# 48

# %%
## problem 1  find a tuple form for  lift floor cliking record. 
lift_record=()
lift_record=lift_record+(int(input("passenger click floor no.:")),)
lift_record=lift_record+(int(input("passenger click floor no.:")),)
lift_record=lift_record+(int(input("passenger click floor no.:")),)
lift_record=lift_record+(int(input("passenger click floor no.:")),)
lift_record=lift_record+(int(input("passenger click floor no.:")),)
lift_record
# Out:
# (4, 5, 9, 2, 3)

# %%
(5,6,7)+(8,)
# Out:
# (5, 6, 7, 8)

# %%
(8)
# Out:
# 8

# %%
(8,)
# Out:
# (8,)
